# %% [markdown]
# # National Level Analysis
# Use statistical methods to determine correlations between water and electricity usage, and data center constructions over time.

# %%
# load data
import pickle
import pandas as pd

data = pd.read_pickle("../data/merged_state_data_2000_2020.pkl")

# %%
# aggregate by year 
national_df = data.groupby('year').agg({
    'q_under_construction_facilities': 'sum',
    'electricity_usage': 'sum',
    'water_usage': 'sum'
}).reset_index()

national_df
# Out:
#     year  q_under_construction_facilities  electricity_usage    water_usage
# 0   2000                              0.0       3.311918e+09  402583.963500
# 1   2001                              0.0       3.281284e+09  407405.341641
# 2   2002                              0.0       3.359914e+09  407434.899417
# 3   2003                              0.0       3.486925e+09  408840.091052
# 4   2004                              0.0       3.540256e+09  408871.954327
# 5   2005                              0.0       3.653462e+09  418425.585716
# 6   2006                              0.0       3.662561e+09  425019.175357
# 7   2007                              0.0       3.756388e+09  427849.754624
# 8   2008                              0.0       3.726311e+09  423509.307311
# 9   2009                              0.0       3.589027e+09  422444.805165
# 10  2010                              0.0       3.747129e+09  416705.467220
# 11  2011                              0.0       3.742174e+09  431920.259010
# 12  2012                              0.0       3.687330e+09  427178.332657
# 13  2013                              0.0       3.717243e+09  423817.330249
# 14  2014                              0.0       3.756943e+09  424416.055654
# 15  2015                              0.0       3.751356e+09  419897.675707
# 16  2016                              0.0       3.754965e+09  420899.120260
# 17  2017                              0.0       3.715833e+09  427469.341306
# 18  2018                              0.0       3.851520e+09  431274.587343
# 19  2019                              0.0       3.803518e+09  427113.215435
# 20  2020                              0.0       3.711127e+09  433071.189684
